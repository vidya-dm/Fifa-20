# %%
import pandas as pd
import urllib.request

# %%
! install patool
# Out:
# install: missing destination file operand after 'patool'
# Try 'install --help' for more information.

# %%
import pandas as pd
from io import StringIO, BytesIO, TextIOWrapper
from zipfile import ZipFile

# %%
dm_url = 'https://d3ilbtxij3aepc.cloudfront.net/projects/CDS-Capstone-Projects/'
fifa_dm_url = 'PRCP-1004-Fifa20.zip'
resp = urllib.request.urlopen(fifa_dm_url+  urllib.request.quote(fifa_dm_url))

zipfile = ZipFile(BytesIO(resp.read()))

data = TextIOWrapper(zipfile.open('PRCP-1004-Fifa20.csv'), encoding='utf-8')

df = pd.read_csv(data)



"""
uci_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00544/'
obesity_levels_uci_url = 'ObesityDataSet_raw_and_data_sinthetic (2).zip'
resp = urllib.request.urlopen(uci_url +  urllib.request.quote(obesity_levels_uci_url))

zipfile = ZipFile(BytesIO(resp.read()))

data = TextIOWrapper(zipfile.open('ObesityDataSet_raw_and_data_sinthetic.csv'), encoding='utf-8')

df = pd.read_csv(data)
"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-f83fb39d8a1a> in <cell line: 3>()
#       1 dm_url = 'https://d3ilbtxij3aepc.cloudfront.net/projects/CDS-Capstone-Projects/'
#       2 fifa_dm_url = 'PRCP-1004-Fifa20.zip'
# ----> 3 resp = urllib.request.urlopen(fifa_dm_url+  urllib.request.quote(fifa_dm_url))
#       4
#       5 zipfile = ZipFile(BytesIO(resp.read()))
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     501         # accept a URL or a Request object
#     502         if isinstance(fullurl, str):
# --> 503             req = Request(fullurl, data)
# ...

# %%
import pandas as pd
from io import StringIO, BytesIO, TextIOWrapper
from zipfile import ZipFile

uci_url = 'https://d3ilbtxij3aepc.cloudfront.net/projects/CDS-Capstone-Projects/'
fifa20_uci_url = 'PRCP-1004-Fifa20.zip'
resp = urllib.request.urlopen(uci_url +  urllib.request.quote('fifa20_uci_url'))

zipfile = ZipFile(BytesIO(resp.read()))

data = TextIOWrapper(zipfile.open('PRCP-1004-Fifa20.csv'), encoding='utf-8')

df = pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-20-3433d74bd960> in <cell line: 7>()
#       5 uci_url = 'https://d3ilbtxij3aepc.cloudfront.net/projects/CDS-Capstone-Projects/'
#       6 fifa20_uci_url = 'PRCP-1004-Fifa20.zip'
# ----> 7 resp = urllib.request.urlopen(uci_url +  urllib.request.quote('fifa20_uci_url'))
#       8
#       9 zipfile = ZipFile(BytesIO(resp.read()))
#
# /usr/lib/python3.10/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214     else:
#     215         opener = _opener
# --> 216     return opener.open(url, data, timeout)
#     217
#     218 def install_opener(opener):
#
# /usr/lib/python3.10/urllib/request.py in open(self, fullurl, data, timeout)
#     523         for processor in self.process_response.get(protocol, []):
#     524             meth = getattr(processor, meth_name)
# ...

# %%
import pandas as pd
df = pd.read_csv("https://d3ilbtxij3aepc.cloudfront.net/projects/CDS-Capstone-Projects/PRCP-1004-Fifa20.zip")

# %%
# installing package
# !pip install pandas-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.4/324.4 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 353.0/353.0 kB 39.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.7/102.7 kB 14.0 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.5/679.5 kB 55.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 36.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.4/455.4 kB 51.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 85.1 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=db14057718f30672860c80ed3e09b7b3b575af2861fdff7852f86b702203a3a8
#   Stored in directory: /root/.cache/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
# Successfully built htmlmin
# ...
#   Attempting uninstall: wordcloud
# ...

# %%
df=pd.read_csv('/content/players_20.csv')

# %%
#!pip install dtale
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 120.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 8.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 54.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.7/219.7 kB 27.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 122.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 137.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.7/33.7 MB 18.8 MB/s eta 0:00:00
# ...

# %%
import dtale

import dtale.app as dtale_app

df=pd.read_csv('/content/players_20.csv')
dtale_app.USE_COLAB = True
dtale.show(df)
# Out:
# /usr/local/lib/python3.10/dist-packages/dtale/views.py:778: FutureWarning:
#
# ['player_tags', 'team_position', 'loaned_from', 'joined', 'nation_position', 'player_traits', 'ls', 'st', 'rs', 'lw', 'lf', 'cf', 'rf', 'rw', 'lam', 'cam', 'ram', 'lm', 'lcm', 'cm', 'rcm', 'rm', 'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
# https://q18lucvil5-496ff2e9c6d22116-40000-colab.googleusercontent.com/dtale/main/1

# %%
# !pip install sweetviz
#importing sweetviz and visualizing our data
import sweetviz as sv
sweet_report = sv.analyze(df)
sweet_report.show_html('sweetviz_report.html')
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 39.2 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.10/dist-packages/sweetviz/dataframe_report.py:74: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# /usr/local/lib/python3.10/dist-packages/sweetviz/dataframe_report.py:109: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#                                              |          | [  0%]   00:00 -> (? left)
# /usr/local/lib/python3.10/dist-packages/sweetviz/series_analyzer_numeric.py:25: FutureWarning:
#
# The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#
# /usr/local/lib/python3.10/dist-packages/sweetviz/series_analyzer_text.py:19: FutureWarning:
#
# iteritems is deprecated and will be removed in a future version. Use .items instead.
#
# ...
